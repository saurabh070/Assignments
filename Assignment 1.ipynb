# %%
Q1. In the below elements which of them are values or an expression? 

* 
'hello'
-87.8
- 
/ 
+
6 


Ans:

hello, -87.8, 6 are the values here & *, -, /, + are expressions
# Out:
#   File "C:\Users\KAKASHI\AppData\Local\Temp/ipykernel_9592/2314426109.py", line 1
#     Q1. In the below elements which of them are values or an expression?
#            ^
# SyntaxError: invalid syntax

# %% [markdown]
# Q2. What is the difference between string and variable?
#
# Ans:
# String is a data type and variable is a container in which values are hold or assigned.
# eg: a = "ineuron"
#
# here a is variable hold a string value "ineuron".

# %% [markdown]
# Q3. Describe three different data types.
#
# Ans:
#     Data type literally means what type of value is stored in a particular variable.
#     some examples of data types are:
#         1. int :- the integers values
#         2: float :- the decimal point values or rational numbers
#         3: str :- string values (usually contained within single or double qoutes)

# %% [markdown]
# Q4. What is an expression made up of? What do all expressions do?
#
# Ans:
#     Experession are made up of operators (like +, -, /, *) and operands (on which operations are done)
#     The use of expression is to evaluate certain calculations as per requirement
#     eg: 40 + 10    #arithematic expression

# %% [markdown]
# Q5. This assignment statements, like spam = 10. What is the difference between an expression and a statement?
#
# Ans:
#
#     The assignment statement above gives variable a independent value which wont change in calculation unless it's stored again with the new value.
#     The expression contains more than 1 variable hence the value it gets after calculation is dependent(i.e. will change as per calculation and operations)

# %% [markdown]
# Q6. After running the following code, what does the variable bacon contain?
# bacon = 22
# bacon + 1
#
# Ans:
#     No changes appears because new value is not assigned to bacon and printing bacon will simply print the assignment statement which is 22

# %% [markdown]
# Q7. What should the values of the following two terms be?
# 'spam' + 'spamspam'
# 'spam' * 3
#
# Ans:
# Both the expression will return same result i.e, 'spamspamspam'
# 'spam' + 'spamspam' this expression is doing concatination of 2 strings
# 'spam' * 3 this expression is repeating the string 3 times

# %% [markdown]
# Q8. Why is eggs a valid variable name while 100 is invalid?
#
# Ans:
#     Variable name must start with alphabet or underscore, numerics are acceptable after the first character only.

# %% [markdown]
# Q9. What three functions can be used to get the integer, floating-point number, or string version of a value?
#
# Ans:
#     for integers use int()
#     for floating point values use float()
#     for string values use str()

# %% [markdown]
# Q10. Why does this expression cause an error? How can you fix it?
# 'I have eaten ' + 99 + ' burritos.'
#
# Ans:
#     It causes error because 99 is integer type. It can be fixed if 99 is writen within qoutes or type casted to string.
